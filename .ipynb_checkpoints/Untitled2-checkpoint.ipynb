# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import models, layers, losses, metrics, callbacks

# %matplotlib inline

# %%
df = pd.read_csv('avocado.csv')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df = df[df.type == 'conventional']

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df = df[df.region == 'TotalUS']
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2652           0  2015-12-27          0.95   27297983.67  9626901.09
# 2653           1  2015-12-20          0.98   25083647.17  8710021.76
# 2654           2  2015-12-13          0.93   28041335.38  9855053.66
# 2655           3  2015-12-06          0.89   28800396.57  9405464.36
# 2656           4  2015-11-29          0.99   22617999.38  8094803.56
#
#              4225        4770  Total Bags  Small Bags  Large Bags  \
# 2652  10197890.05  1184340.09  6288852.44  4850404.09  1252626.31
# 2653   9329861.85  1201020.01  5842743.55  4618389.66  1025048.77
# 2654  10805838.91  1016163.17  6364279.64  4964462.13  1371440.28
# 2655  12160838.62   931830.63  6302262.96  5005077.36  1233956.21
# 2656   9003178.41   731008.41  4789009.00  3901953.04   856560.34
#
#       XLarge Bags          type  year   region
# 2652    185822.04  conventional  2015  TotalUS
# 2653    199305.12  conventional  2015  TotalUS
# ...

# %%
df.drop(['region', 'type'], inplace=True, axis=1)
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2652           0  2015-12-27          0.95   27297983.67  9626901.09
# 2653           1  2015-12-20          0.98   25083647.17  8710021.76
# 2654           2  2015-12-13          0.93   28041335.38  9855053.66
# 2655           3  2015-12-06          0.89   28800396.57  9405464.36
# 2656           4  2015-11-29          0.99   22617999.38  8094803.56
#
#              4225        4770  Total Bags  Small Bags  Large Bags  \
# 2652  10197890.05  1184340.09  6288852.44  4850404.09  1252626.31
# 2653   9329861.85  1201020.01  5842743.55  4618389.66  1025048.77
# 2654  10805838.91  1016163.17  6364279.64  4964462.13  1371440.28
# 2655  12160838.62   931830.63  6302262.96  5005077.36  1233956.21
# 2656   9003178.41   731008.41  4789009.00  3901953.04   856560.34
#
#       XLarge Bags  year
# 2652    185822.04  2015
# 2653    199305.12  2015
# 2654     28377.23  2015
# 2655     63229.39  2015
# 2656     30495.62  2015

# %%
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2652           0  2015-12-27          0.95   27297983.67  9626901.09
# 2653           1  2015-12-20          0.98   25083647.17  8710021.76
# 2654           2  2015-12-13          0.93   28041335.38  9855053.66
# 2655           3  2015-12-06          0.89   28800396.57  9405464.36
# 2656           4  2015-11-29          0.99   22617999.38  8094803.56
#
#              4225        4770  Total Bags  Small Bags  Large Bags  \
# 2652  10197890.05  1184340.09  6288852.44  4850404.09  1252626.31
# 2653   9329861.85  1201020.01  5842743.55  4618389.66  1025048.77
# 2654  10805838.91  1016163.17  6364279.64  4964462.13  1371440.28
# 2655  12160838.62   931830.63  6302262.96  5005077.36  1233956.21
# 2656   9003178.41   731008.41  4789009.00  3901953.04   856560.34
#
#       XLarge Bags  year
# 2652    185822.04  2015
# 2653    199305.12  2015
# 2654     28377.23  2015
# 2655     63229.39  2015
# 2656     30495.62  2015

# %%
df.drop([ 'year'], inplace=True, axis=1)
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2652           0  2015-12-27          0.95   27297983.67  9626901.09
# 2653           1  2015-12-20          0.98   25083647.17  8710021.76
# 2654           2  2015-12-13          0.93   28041335.38  9855053.66
# 2655           3  2015-12-06          0.89   28800396.57  9405464.36
# 2656           4  2015-11-29          0.99   22617999.38  8094803.56
#
#              4225        4770  Total Bags  Small Bags  Large Bags  XLarge Bags
# 2652  10197890.05  1184340.09  6288852.44  4850404.09  1252626.31    185822.04
# 2653   9329861.85  1201020.01  5842743.55  4618389.66  1025048.77    199305.12
# 2654  10805838.91  1016163.17  6364279.64  4964462.13  1371440.28     28377.23
# 2655  12160838.62   931830.63  6302262.96  5005077.36  1233956.21     63229.39
# 2656   9003178.41   731008.41  4789009.00  3901953.04   856560.34     30495.62

# %%
df.plot(x='Date', y=['AveragePrice', 'Total Volume', 'Total Bags'])

# %%
df.plot(x='Date', y='AveragePrice')

# %%
df.plot(x='Date', y='Total Volume')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 2652 to 9101
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    169 non-null    int64
#  1   Date          169 non-null    object
#  2   AveragePrice  169 non-null    float64
#  3   Total Volume  169 non-null    float64
#  4   4046          169 non-null    float64
#  5   4225          169 non-null    float64
#  6   4770          169 non-null    float64
#  7   Total Bags    169 non-null    float64
#  8   Small Bags    169 non-null    float64
#  9   Large Bags    169 non-null    float64
#  10  XLarge Bags   169 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 15.8+ KB

# %%
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2652           0  2015-12-27          0.95   27297983.67  9626901.09
# 2653           1  2015-12-20          0.98   25083647.17  8710021.76
# 2654           2  2015-12-13          0.93   28041335.38  9855053.66
# 2655           3  2015-12-06          0.89   28800396.57  9405464.36
# 2656           4  2015-11-29          0.99   22617999.38  8094803.56
#
#              4225        4770  Total Bags  Small Bags  Large Bags  XLarge Bags
# 2652  10197890.05  1184340.09  6288852.44  4850404.09  1252626.31    185822.04
# 2653   9329861.85  1201020.01  5842743.55  4618389.66  1025048.77    199305.12
# 2654  10805838.91  1016163.17  6364279.64  4964462.13  1371440.28     28377.23
# 2655  12160838.62   931830.63  6302262.96  5005077.36  1233956.21     63229.39
# 2656   9003178.41   731008.41  4789009.00  3901953.04   856560.34     30495.62

# %%
df.loc[: ,'AveragePrice':] = scaler.fit_transform(df.loc[:, 'AveragePrice':])

# %%
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 2652           0  2015-12-27     -0.818027     -1.055261 -0.967997 -0.601372
# 2653           1  2015-12-20     -0.645219     -1.418269 -1.340274 -0.969768
# 2654           2  2015-12-13     -0.933232     -0.933400 -0.875361 -0.343354
# 2655           3  2015-12-06     -1.163643     -0.808963 -1.057906  0.231716
# 2656           4  2015-11-29     -0.587616     -1.822476 -1.590068 -1.108415
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags
# 2652  0.618869   -0.923574   -0.975716   -0.829323     0.555998
# 2653  0.657729   -1.065568   -1.081021   -1.062111     0.683294
# 2654  0.227057   -0.899566   -0.923949   -0.707789    -0.930463
# 2655  0.030582   -0.919305   -0.905515   -0.848421    -0.601418
# 2656 -0.437286   -1.400965   -1.406190   -1.234457    -0.910463

# %%
df.plot(x='Date', y=['AveragePrice', 'Total Volume', 'Total Bags'])

# %%
df.drop(['4046', '4225', '4770', 'Small Bags', 'Large Bags', 'XLarge Bags'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume  Total Bags
# 2652           0  2015-12-27     -0.818027     -1.055261   -0.923574
# 2653           1  2015-12-20     -0.645219     -1.418269   -1.065568
# 2654           2  2015-12-13     -0.933232     -0.933400   -0.899566
# 2655           3  2015-12-06     -1.163643     -0.808963   -0.919305
# 2656           4  2015-11-29     -0.587616     -1.822476   -1.400965

# %%
df.plot(x='Date', y=['AveragePrice', 'Total Volume', 'Total Bags'], kind='line', figsize=(10, 8))

# %%
df.rename(mapper={'AveragePrice': 'price', 'Total Volume': 'total', 'Total Bags': 'bags'}, inplace=True, axis=1)

# %%
df.head()
# Out:
#       Unnamed: 0        Date     price     total      bags
# 2652           0  2015-12-27 -0.818027 -1.055261 -0.923574
# 2653           1  2015-12-20 -0.645219 -1.418269 -1.065568
# 2654           2  2015-12-13 -0.933232 -0.933400 -0.899566
# 2655           3  2015-12-06 -1.163643 -0.808963 -0.919305
# 2656           4  2015-11-29 -0.587616 -1.822476 -1.400965

# %%
df.rename({'Date': 'date'}, inplace=True, axis=1)

# %%
df.head()
# Out:
#       Unnamed: 0        date     price     total      bags
# 2652           0  2015-12-27 -0.818027 -1.055261 -0.923574
# 2653           1  2015-12-20 -0.645219 -1.418269 -1.065568
# 2654           2  2015-12-13 -0.933232 -0.933400 -0.899566
# 2655           3  2015-12-06 -1.163643 -0.808963 -0.919305
# 2656           4  2015-11-29 -0.587616 -1.822476 -1.400965

# %%
df.date = pd.to_datetime(df.date)
df.sort_values(by=['date'], inplace=True, ascending=True)

# %%
df.head()
# Out:
#       Unnamed: 0       date     price     total      bags
# 2703          51 2015-01-04 -0.818027 -0.395209 -1.493292
# 2702          50 2015-01-11 -0.472411 -0.765824 -1.487421
# 2701          49 2015-01-18 -0.357205 -0.769116 -1.444552
# 2700          48 2015-01-25 -0.299602 -0.863075 -1.397405
# 2699          47 2015-02-01 -1.163643  1.790244 -1.211447

# %%
df.count()
# Out:
# Unnamed: 0    169
# date          169
# price         169
# total         169
# bags          169
# dtype: int64

# %%
df.head()
# df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.set_index('date')
df.drop(['date'], axis=1, inplace=True)
df.head()
# Out:
#          price     total      bags
# 2703 -0.818027 -0.395209 -1.493292
# 2702 -0.472411 -0.765824 -1.487421
# 2701 -0.357205 -0.769116 -1.444552
# 2700 -0.299602 -0.863075 -1.397405
# 2699 -1.163643  1.790244 -1.211447

# %%
import tensorflow as tf
WINDOW_SIZE = 12
def batch_dataset(dataset):
    dataset_batched = dataset.batch(WINDOW_SIZE, drop_remainder=True)
    return dataset_batched
ds_data = tf.data.Dataset.from_tensor_slices(tf.constant(df.values, dtype=tf.float32)) \
.window(WINDOW_SIZE, shift=1).flat_map(batch_dataset)
ds_label = tf.data.Dataset.from_tensor_slices(tf.constant(df.values[WINDOW_SIZE:], dtype=tf.float32))
ds_train = tf.data.Dataset.zip((ds_data, ds_label)).batch(169).cache()

# %%
print(len(list(ds_train.as_numpy_iterator())))
for i in ds_train.as_numpy_iterator()[0]:
    print(i)
    print('*'*100)
# Out:
# 1
# (<tf.Tensor: shape=(157, 12, 3), dtype=float32, numpy=
# array([[[-0.8180269 , -0.39520907, -1.4932919 ],
#         [-0.47241053, -0.76582354, -1.4874212 ],
#         [-0.35720506, -0.76911604, -1.4445516 ],
#         ...,
#         [-0.4148078 , -0.5967806 , -1.2469239 ],
#         [-0.29960236, -0.6824324 , -1.3603561 ],
#         [-0.47241053, -0.20024519, -1.3051693 ]],
#
#        [[-0.47241053, -0.76582354, -1.4874212 ],
#         [-0.35720506, -0.76911604, -1.4445516 ],
#         [-0.29960236, -0.86307526, -1.3974049 ],
#         ...,
#         [-0.29960236, -0.6824324 , -1.3603561 ],
#         [-0.47241053, -0.20024519, -1.3051693 ],
#         [-0.29960236, -0.6151496 , -1.3001648 ]],
#
#        [[-0.35720506, -0.76911604, -1.4445516 ],
#         [-0.29960236, -0.86307526, -1.3974049 ],
#         [-1.1636432 ,  1.7902437 , -1.2114466 ],
#         ...,
#         [-0.47241053, -0.20024519, -1.3051693 ],
#         [-0.29960236, -0.6151496 , -1.3001648 ],
# ...
